# %% [markdown]
# # Budget Analysis
#
# ---
#
# ## Environment Setup

# %%
# Initial Imports
import os
import plaid
import requests
from pathlib import Path
import datetime
import json
import pandas as pd
from dotenv import load_dotenv

# %matplotlib inline

# %%
# Helper functions

def pretty_print_response(response):
    """
    This function formats a JSON file to pretty printing it in the screen.
    """
    print(json.dumps(response, indent=4, sort_keys=True))

# %%
# Set API Key path to env file
api_key_path = Path('C:/Users/markf/Desktop/Fintech SMU/API_Keys/.env')

# %%
# Set environment variables from the .env file
load_dotenv(api_key_path)
# Out:
# True

# %%
# Extract API keys from environment variables
PLAID_CLIENT_ID = os.getenv("PLAID_CLIENT_ID")
PLAID_SBX_SECRET_KEY = os.getenv("PLAID_SBX_SECRET_KEY")
PLAID_PUBLIC_KEY = os.getenv("PLAID_PUBLIC_KEY")

# %%
print(type(PLAID_CLIENT_ID))
print(type(PLAID_SBX_SECRET_KEY))
print(type(PLAID_PUBLIC_KEY))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# ---
#
# ## Plaid Access Token
#
# In this section, you will use the `plaid-python` API to generate the correct authentication tokens to access data in the free developer Sandbox. This mimics how you might connect to your own account or a customer account, but due to privacy issues, this homework will only require connecting to and analyzing the fake data from the developer sandbox that Plaid provides.
#
# Complete the following steps to generate an access token:
#
# 1. Create a client to connect to plaid
#
# 2. Use the client to generate a public token and request the following items: ['transactions', 'income', 'assets']
#
# 3. Exchange the public token for an access token
#
# 4. Test the access token by requesting and printing the available test accounts

# %% [markdown]
# ### 1. Create a client to connect to plaid

# %%
# Create the client object
client = plaid.Client(client_id=PLAID_CLIENT_ID, secret=PLAID_SBX_SECRET_KEY, public_key=PLAID_PUBLIC_KEY, environment='sandbox')

# %%
# Set the institution id
INSTITUTION_ID = "ins_109508"

# %% [markdown]
# ### 2. Generate a public token

# %%
# Create the public token
create_tkn_response = client.Sandbox.public_token.create(INSTITUTION_ID, ['transactions','income','assets'])

# Print the public token
print(create_tkn_response)
# Out:
# {'public_token': 'public-sandbox-1ebf85da-eb9e-4555-ae01-329984db2bb0', 'request_id': 'voMJTvHpgIn8LoC'}

# %% [markdown]
# ### 3. Exchange the public token for an access token

# %%
# Retrieve the access token
exchange_response = client.Item.public_token.exchange(create_tkn_response['public_token'])

# Print the access toke
print(exchange_response)

# Store the access token in a Python variable
access_token = exchange_response['access_token']
# Out:
# {'access_token': 'access-sandbox-84a3cef5-08b8-432a-8020-8a23c123263f', 'item_id': 'RPGlqyZMDlCBXxwxwd6WhPRwL6l9jNuRvPGgm', 'request_id': 'T4WnhC1sbG1xeZ4'}

# %% [markdown]
# ### 4. Fetch Accounts

# %%
# Retrieve accounts
accounts = client.Accounts.get(access_token)
# Print accounts
print(json.dumps(accounts, indent = 4, sort_keys = True))
# Out:
# {
#     "accounts": [
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "balances": {
#                 "available": 100,
#                 "current": 110,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "0000",
#             "name": "Plaid Checking",
#             "official_name": "Plaid Gold Standard 0% Interest Checking",
#             "subtype": "checking",
#             "type": "depository"
#         },
#         {
#             "account_id": "B8koJKvZboiWgNJNJjqkIgEdW9AwJ4SwG3Ekl",
#             "balances": {
#                 "available": 200,
#                 "current": 210,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "1111",
#             "name": "Plaid Saving",
#             "official_name": "Plaid Silver Standard 0.1% Interest Saving",
#             "subtype": "savings",
#             "type": "depository"
#         },
#         {
#             "account_id": "3aJZMXLbAZIwVePeP1rlhkVjy6Ad4ofqa96WL",
#             "balances": {
#                 "available": null,
#                 "current": 1000,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "2222",
#             "name": "Plaid CD",
#             "official_name": "Plaid Bronze Standard 0.2% Interest CD",
#             "subtype": "cd",
#             "type": "depository"
#         },
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "balances": {
#                 "available": null,
#                 "current": 410,
#                 "iso_currency_code": "USD",
#                 "limit": 2000,
#                 "unofficial_currency_code": null
#             },
#             "mask": "3333",
#             "name": "Plaid Credit Card",
#             "official_name": "Plaid Diamond 12.5% APR Interest Credit Card",
#             "subtype": "credit card",
#             "type": "credit"
#         },
#         {
#             "account_id": "dKZR13NX6RIGBJdJdlwmIBoRpqraM6fZ34KXo",
#             "balances": {
#                 "available": 43200,
#                 "current": 43200,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "4444",
#             "name": "Plaid Money Market",
#             "official_name": "Plaid Platinum Standard 1.85% Interest Money Market",
#             "subtype": "money market",
#             "type": "depository"
#         },
#         {
#             "account_id": "aA7RQrPXbRCQG8Z8ZdJBUkDqaPlb5vf79gwXR",
#             "balances": {
#                 "available": null,
#                 "current": 320.76,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "5555",
#             "name": "Plaid IRA",
#             "official_name": null,
#             "subtype": "ira",
#             "type": "investment"
#         },
#         {
#             "account_id": "44ZA1kpb5ACrvakakoQBTXvlyKknR8fdxazmd",
#             "balances": {
#                 "available": null,
#                 "current": 23631.9805,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "6666",
#             "name": "Plaid 401k",
#             "official_name": null,
#             "subtype": "401k",
#             "type": "investment"
#         },
#         {
#             "account_id": "NdPLJjMNDLFedrMrMzavSXpJgno6ZLfW1MdVy",
#             "balances": {
#                 "available": null,
#                 "current": 65262,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "7777",
#             "name": "Plaid Student Loan",
#             "official_name": null,
#             "subtype": "student",
#             "type": "loan"
#         },
#         {
#             "account_id": "P47LJZjWDLCoRGZGZ3wBTXpDrKbVdWf74zaKX",
#             "balances": {
#                 "available": null,
#                 "current": 56302.06,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "8888",
#             "name": "Plaid Mortgage",
#             "official_name": null,
#             "subtype": "mortgage",
#             "type": "loan"
#         }
#     ],
#     "item": {
#         "available_products": [
#             "auth",
#             "balance",
#             "credit_details",
#             "identity",
#             "investments",
#             "liabilities"
#         ],
#         "billed_products": [
#             "assets",
#             "income",
#             "transactions"
#         ],
#         "consent_expiration_time": null,
#         "error": null,
#         "institution_id": "ins_109508",
#         "item_id": "RPGlqyZMDlCBXxwxwd6WhPRwL6l9jNuRvPGgm",
#         "webhook": ""
#     },
#     "request_id": "Mw4Q5ZG40yUv1bc"
# }

# %% [markdown]
# ---
#
# # Account Transactions with Plaid
#
# In this section, you will use the Plaid Python SDK to connect to the Developer Sandbox account and grab a list of transactions. You will need to complete the following steps:
#
#
# 1. Use the access token to fetch the transactions for the last 90 days
#
# 2. Print the categories for each transaction type
#
# 3. Create a new DataFrame using the following fields from the JSON transaction data: `date, name, amount, category`. (For categories with more than one label, just use the first category label in the list)
#
# 4. Convert the data types to the appropriate types (i.e. datetimeindex for the date and float for the amount)

# %% [markdown]
# ### 1. Fetch the Transactions for the last 90 days

# %%
# Set the start and end date 90 days from today
start_date = '{:%Y-%m-%d}'.format(datetime.datetime.now() + datetime.timedelta(-90))
end_date = '{:%Y-%m-%d}'.format(datetime.datetime.now())

# Retrieve the transactions for the last 90 days
transaction_response = client.Transactions.get(access_token,start_date,end_date)


# Print the transactions
print(json.dumps(transaction_response, indent = 4, sort_keys = True))
# Out:
# {
#     "accounts": [
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "balances": {
#                 "available": 100,
#                 "current": 110,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "0000",
#             "name": "Plaid Checking",
#             "official_name": "Plaid Gold Standard 0% Interest Checking",
#             "subtype": "checking",
#             "type": "depository"
#         },
#         {
#             "account_id": "B8koJKvZboiWgNJNJjqkIgEdW9AwJ4SwG3Ekl",
#             "balances": {
#                 "available": 200,
#                 "current": 210,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "1111",
#             "name": "Plaid Saving",
#             "official_name": "Plaid Silver Standard 0.1% Interest Saving",
#             "subtype": "savings",
#             "type": "depository"
#         },
#         {
#             "account_id": "3aJZMXLbAZIwVePeP1rlhkVjy6Ad4ofqa96WL",
#             "balances": {
#                 "available": null,
#                 "current": 1000,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "2222",
#             "name": "Plaid CD",
#             "official_name": "Plaid Bronze Standard 0.2% Interest CD",
#             "subtype": "cd",
#             "type": "depository"
#         },
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "balances": {
#                 "available": null,
#                 "current": 410,
#                 "iso_currency_code": "USD",
#                 "limit": 2000,
#                 "unofficial_currency_code": null
#             },
#             "mask": "3333",
#             "name": "Plaid Credit Card",
#             "official_name": "Plaid Diamond 12.5% APR Interest Credit Card",
#             "subtype": "credit card",
#             "type": "credit"
#         },
#         {
#             "account_id": "dKZR13NX6RIGBJdJdlwmIBoRpqraM6fZ34KXo",
#             "balances": {
#                 "available": 43200,
#                 "current": 43200,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "4444",
#             "name": "Plaid Money Market",
#             "official_name": "Plaid Platinum Standard 1.85% Interest Money Market",
#             "subtype": "money market",
#             "type": "depository"
#         },
#         {
#             "account_id": "aA7RQrPXbRCQG8Z8ZdJBUkDqaPlb5vf79gwXR",
#             "balances": {
#                 "available": null,
#                 "current": 320.76,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "5555",
#             "name": "Plaid IRA",
#             "official_name": null,
#             "subtype": "ira",
#             "type": "investment"
#         },
#         {
#             "account_id": "44ZA1kpb5ACrvakakoQBTXvlyKknR8fdxazmd",
#             "balances": {
#                 "available": null,
#                 "current": 23631.9805,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "6666",
#             "name": "Plaid 401k",
#             "official_name": null,
#             "subtype": "401k",
#             "type": "investment"
#         },
#         {
#             "account_id": "NdPLJjMNDLFedrMrMzavSXpJgno6ZLfW1MdVy",
#             "balances": {
#                 "available": null,
#                 "current": 65262,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "7777",
#             "name": "Plaid Student Loan",
#             "official_name": null,
#             "subtype": "student",
#             "type": "loan"
#         },
#         {
#             "account_id": "P47LJZjWDLCoRGZGZ3wBTXpDrKbVdWf74zaKX",
#             "balances": {
#                 "available": null,
#                 "current": 56302.06,
#                 "iso_currency_code": "USD",
#                 "limit": null,
#                 "unofficial_currency_code": null
#             },
#             "mask": "8888",
#             "name": "Plaid Mortgage",
#             "official_name": null,
#             "subtype": "mortgage",
#             "type": "loan"
#         }
#     ],
#     "item": {
#         "available_products": [
#             "auth",
#             "balance",
#             "credit_details",
#             "identity",
#             "investments",
#             "liabilities"
#         ],
#         "billed_products": [
#             "assets",
#             "income",
#             "transactions"
#         ],
#         "consent_expiration_time": null,
#         "error": null,
#         "institution_id": "ins_109508",
#         "item_id": "RPGlqyZMDlCBXxwxwd6WhPRwL6l9jNuRvPGgm",
#         "webhook": ""
#     },
#     "request_id": "NDrtJiuR1AycKWH",
#     "total_transactions": 48,
#     "transactions": [
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Airlines and Aviation Services"
#             ],
#             "category_id": "22001000",
#             "date": "2020-05-30",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "United Airlines",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "dKZR13NX6RIGBJdJdlwmIBoRjvBQeLCZQj5oz",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": 6.33,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Taxi"
#             ],
#             "category_id": "22016000",
#             "date": "2020-05-28",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Uber",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "kaARvQpDWRI9a8w8wMA5H3EmlW35xeIWdlgrk",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants"
#             ],
#             "category_id": "13005000",
#             "date": "2020-05-25",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Tectra Inc",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "aA7RQrPXbRCQG8Z8ZdJBUkDqBpkMEzs7QBlp5",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "account_owner": null,
#             "amount": 2078.5,
#             "authorized_date": null,
#             "category": [
#                 "Payment"
#             ],
#             "category_id": "16000000",
#             "date": "2020-05-24",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "AUTOMATIC PAYMENT - THANK",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "P47LJZjWDLCoRGZGZ3wBTXpD98XkwZC7WPBE4",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Fast Food"
#             ],
#             "category_id": "13005032",
#             "date": "2020-05-24",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "KFC",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "NdPLJjMNDLFedrMrMzavSXpJqvXjx3CW54BL4",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Shops",
#                 "Sporting Goods"
#             ],
#             "category_id": "19046000",
#             "date": "2020-05-24",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Madison Bicycle Shop",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "44ZA1kpb5ACrvakakoQBTXvlgAX53eCdAQN8y",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "B8koJKvZboiWgNJNJjqkIgEdW9AwJ4SwG3Ekl",
#             "account_owner": null,
#             "amount": 25,
#             "authorized_date": null,
#             "category": [
#                 "Payment",
#                 "Credit Card"
#             ],
#             "category_id": "16001000",
#             "date": "2020-05-15",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "CREDIT CARD 3333 PAYMENT *//",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "B8koJKvZboiWgNJNJjqkIgEdNmg8rPHw8b6qg",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": 5.4,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Taxi"
#             ],
#             "category_id": "22016000",
#             "date": "2020-05-15",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Uber",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "l4AR6QJDnRC41eQeQDmLCNMqVPN3pvFZdVG1k",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "dKZR13NX6RIGBJdJdlwmIBoRpqraM6fZ34KXo",
#             "account_owner": null,
#             "amount": 5850,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Debit"
#             ],
#             "category_id": "21006000",
#             "date": "2020-05-14",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "ACH Electronic CreditGUSTO PAY 123456",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": "ACH",
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "7jXgo5LbDgClJwbwbABacXBZJnXlpWCgnoA4W",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "3aJZMXLbAZIwVePeP1rlhkVjy6Ad4ofqa96WL",
#             "account_owner": null,
#             "amount": 1000,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Deposit"
#             ],
#             "category_id": "21007000",
#             "date": "2020-05-14",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "CD DEPOSIT .INITIAL.",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "xoK6vWRqn6ToDRlRlzv9TZ6deNZ4jwinV3pmM",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "account_owner": null,
#             "amount": 78.5,
#             "authorized_date": null,
#             "category": [
#                 "Recreation",
#                 "Gyms and Fitness Centers"
#             ],
#             "category_id": "17018000",
#             "date": "2020-05-13",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Touchstone Climbing",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "jd7Rvmk5nRFGW8k8k7mjIjA4V7jrb9C1LVzoX",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": -500,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Airlines and Aviation Services"
#             ],
#             "category_id": "22001000",
#             "date": "2020-05-13",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "United Airlines",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "qeA6v1qDy6femV8V8o4LS56b1D5KymHd7zA81",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": 12,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Fast Food"
#             ],
#             "category_id": "13005032",
#             "date": "2020-05-12",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": "3322"
#             },
#             "name": "McDonald's",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "KBPLJNydDLuaKleleqL8TEkoDLEZv1tVAxWgb",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": 4.33,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Coffee Shop"
#             ],
#             "category_id": "13005043",
#             "date": "2020-05-12",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Starbucks",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "rQw6vWKDn6sQgn4n4ZopUXzxEpXRLjCl6eqL6",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": 89.4,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants"
#             ],
#             "category_id": "13005000",
#             "date": "2020-05-11",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "SparkFun",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "z8z6vwArX6i86wvwvyd1FKjqALKGNJHoL5JDm",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "B8koJKvZboiWgNJNJjqkIgEdW9AwJ4SwG3Ekl",
#             "account_owner": null,
#             "amount": -4.22,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Credit"
#             ],
#             "category_id": "21005000",
#             "date": "2020-05-10",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "INTRST PYMNT",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "3aJZMXLbAZIwVePeP1rlhkVjwqk1K5sqnDKGV",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Airlines and Aviation Services"
#             ],
#             "category_id": "22001000",
#             "date": "2020-04-30",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "United Airlines",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "6PvkpbL6EkCegxnxnAPVSKglxbn83WCgRd5eA",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": 6.33,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Taxi"
#             ],
#             "category_id": "22016000",
#             "date": "2020-04-28",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Uber",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "blyRZzwXWRflqpjpjQ3mco53BxXnyKSVwWe18",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants"
#             ],
#             "category_id": "13005000",
#             "date": "2020-04-25",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Tectra Inc",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "RPGlqyZMDlCBXxwxwd6WhPRmz5dJMNiRQnEA5",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "account_owner": null,
#             "amount": 2078.5,
#             "authorized_date": null,
#             "category": [
#                 "Payment"
#             ],
#             "category_id": "16000000",
#             "date": "2020-04-24",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "AUTOMATIC PAYMENT - THANK",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "vLl6vW3Dn6CmW9n9nKXasP73XbEaJxiWD8d1J",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Fast Food"
#             ],
#             "category_id": "13005032",
#             "date": "2020-04-24",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "KFC",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "9e6oJM57EofkKL9L9An6sanNDAxlQLiRmZ6gK",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Shops",
#                 "Sporting Goods"
#             ],
#             "category_id": "19046000",
#             "date": "2020-04-24",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Madison Bicycle Shop",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "ygr6wWDKn6TGKd1d1BXVIJ7rRPGl8dcyQEBwo",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "B8koJKvZboiWgNJNJjqkIgEdW9AwJ4SwG3Ekl",
#             "account_owner": null,
#             "amount": 25,
#             "authorized_date": null,
#             "category": [
#                 "Payment",
#                 "Credit Card"
#             ],
#             "category_id": "16001000",
#             "date": "2020-04-15",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "CREDIT CARD 3333 PAYMENT *//",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "ygr6wWDKn6TGKd1d1BXVIJ7rRPGl8dcyQEBeb",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": 5.4,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Taxi"
#             ],
#             "category_id": "22016000",
#             "date": "2020-04-15",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Uber",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "nPA6vQbDn6CPpZRZR86NcX6JAGlm4Ef6Bz4Nr",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "dKZR13NX6RIGBJdJdlwmIBoRpqraM6fZ34KXo",
#             "account_owner": null,
#             "amount": 5850,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Debit"
#             ],
#             "category_id": "21006000",
#             "date": "2020-04-14",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "ACH Electronic CreditGUSTO PAY 123456",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": "ACH",
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "erwRLxyXWRtrE4Q4QPqxTl5qAd4bemiLwWG3N",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "3aJZMXLbAZIwVePeP1rlhkVjy6Ad4ofqa96WL",
#             "account_owner": null,
#             "amount": 1000,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Deposit"
#             ],
#             "category_id": "21007000",
#             "date": "2020-04-14",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "CD DEPOSIT .INITIAL.",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "NdPLJjMNDLFedrMrMzavSXp5d7qaW3fW1Mwmr",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "account_owner": null,
#             "amount": 78.5,
#             "authorized_date": null,
#             "category": [
#                 "Recreation",
#                 "Gyms and Fitness Centers"
#             ],
#             "category_id": "17018000",
#             "date": "2020-04-13",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Touchstone Climbing",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "mNA6vXaDn6CNW8A8A6Dmtloj76k94NiL51aXP",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": -500,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Airlines and Aviation Services"
#             ],
#             "category_id": "22001000",
#             "date": "2020-04-13",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "United Airlines",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "GqdVJxRzDVfXAqbqbMxyiGADl8ogxPI14bdXb",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": 12,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Fast Food"
#             ],
#             "category_id": "13005032",
#             "date": "2020-04-12",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": "3322"
#             },
#             "name": "McDonald's",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "WZkB3ypMDBuBpNqNq6ElhPGNLB7E63ilGpVDe",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": 4.33,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Coffee Shop"
#             ],
#             "category_id": "13005043",
#             "date": "2020-04-12",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Starbucks",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "AgKoJk4VEoTyB9X9XAnLIXWKJ8eBq7f1vgmdG",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": 89.4,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants"
#             ],
#             "category_id": "13005000",
#             "date": "2020-04-11",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "SparkFun",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
# ...
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "AgKoJk4VEoTyB9X9XAnLIXWKJ8eBq7f1vgm59",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "account_owner": null,
#             "amount": 500,
#             "authorized_date": null,
#             "category": [
#                 "Shops",
#                 "Sporting Goods"
#             ],
#             "category_id": "19046000",
#             "date": "2020-03-25",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Madison Bicycle Shop",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "WZkB3ypMDBuBpNqNq6ElhPGNLB7E63ilGpVjl",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "B8koJKvZboiWgNJNJjqkIgEdW9AwJ4SwG3Ekl",
#             "account_owner": null,
#             "amount": 25,
#             "authorized_date": null,
#             "category": [
#                 "Payment",
#                 "Credit Card"
#             ],
#             "category_id": "16001000",
#             "date": "2020-03-16",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "CREDIT CARD 3333 PAYMENT *//",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "blyRZzwXWRflqpjpjQ3mco53BxXnyKSVwWeQ8",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": 5.4,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Taxi"
#             ],
#             "category_id": "22016000",
#             "date": "2020-03-16",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Uber",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "gB7DoaNXWDuBoZrZrNklh3nRLVvADPSgXKJwa",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "dKZR13NX6RIGBJdJdlwmIBoRpqraM6fZ34KXo",
#             "account_owner": null,
#             "amount": 5850,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Debit"
#             ],
#             "category_id": "21006000",
#             "date": "2020-03-15",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "ACH Electronic CreditGUSTO PAY 123456",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": "ACH",
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "7jXgo5LbDgClJwbwbABacXB8N9JAEWfgGXqB9",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "3aJZMXLbAZIwVePeP1rlhkVjy6Ad4ofqa96WL",
#             "account_owner": null,
#             "amount": 1000,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Deposit"
#             ],
#             "category_id": "21007000",
#             "date": "2020-03-15",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "CD DEPOSIT .INITIAL.",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "44ZA1kpb5ACrvakakoQBTXvWJmgqoefdxaP78",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "xoK6vWRqn6ToDRlRlzv9TZ6dpyKQ3EtnEDjQX",
#             "account_owner": null,
#             "amount": 78.5,
#             "authorized_date": null,
#             "category": [
#                 "Recreation",
#                 "Gyms and Fitness Centers"
#             ],
#             "category_id": "17018000",
#             "date": "2020-03-14",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Touchstone Climbing",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "EA3LJBnKDLCb69Q9QGndIlW5ny1J6riXLoNmj",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": -500,
#             "authorized_date": null,
#             "category": [
#                 "Travel",
#                 "Airlines and Aviation Services"
#             ],
#             "category_id": "22001000",
#             "date": "2020-03-14",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "United Airlines",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "ojy6vmWDn6CjNeDeDkwdfP6ZWb8Xa5iR3Nmzw",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": 12,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Fast Food"
#             ],
#             "category_id": "13005032",
#             "date": "2020-03-13",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": "3322"
#             },
#             "name": "McDonald's",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "L3PAJNQaDAsy7e4e4Kq3IeKgBkGrV1iPJN5RB",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": 4.33,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants",
#                 "Coffee Shop"
#             ],
#             "category_id": "13005043",
#             "date": "2020-03-13",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "Starbucks",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "p7A6vRlDn6fG5j6j6kdnIqVLexlp16ILx5dW8",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "z8z6vwArX6i86wvwvyd1FKjqyVzo58uoGxrer",
#             "account_owner": null,
#             "amount": 89.4,
#             "authorized_date": null,
#             "category": [
#                 "Food and Drink",
#                 "Restaurants"
#             ],
#             "category_id": "13005000",
#             "date": "2020-03-12",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "SparkFun",
#             "payment_channel": "in store",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "1xWAQMLVEACrx9m9mo8KT6WgnXQ3qxC5wM1xD",
#             "transaction_type": "place",
#             "unofficial_currency_code": null
#         },
#         {
#             "account_id": "B8koJKvZboiWgNJNJjqkIgEdW9AwJ4SwG3Ekl",
#             "account_owner": null,
#             "amount": -4.22,
#             "authorized_date": null,
#             "category": [
#                 "Transfer",
#                 "Credit"
#             ],
#             "category_id": "21005000",
#             "date": "2020-03-11",
#             "iso_currency_code": "USD",
#             "location": {
#                 "address": null,
#                 "city": null,
#                 "country": null,
#                 "lat": null,
#                 "lon": null,
#                 "postal_code": null,
#                 "region": null,
#                 "store_number": null
#             },
#             "name": "INTRST PYMNT",
#             "payment_channel": "other",
#             "payment_meta": {
#                 "by_order_of": null,
#                 "payee": null,
#                 "payer": null,
#                 "payment_method": null,
#                 "payment_processor": null,
#                 "ppd_id": null,
#                 "reason": null,
#                 "reference_number": null
#             },
#             "pending": false,
#             "pending_transaction_id": null,
#             "transaction_code": null,
#             "transaction_id": "nPA6vQbDn6CPpZRZR86NcX6JAGlm4Ef6Bz4wr",
#             "transaction_type": "special",
#             "unofficial_currency_code": null
#         }
#     ]
# }

# %% [markdown]
# ### 2. Print the categories for each transaction

# %%
# Create a for-loop to print the categories for each transaction
categories = []
for transactions in transaction_response['transactions']:
    category = transactions['category'][0]
    categories.append(category)
    print(category)
# Out:
# Travel
# Travel
# Food and Drink
# Payment
# Food and Drink
# Shops
# Payment
# Travel
# Transfer
# Transfer
# Recreation
# Travel
# Food and Drink
# Food and Drink
# Food and Drink
# Transfer
# Travel
# Travel
# Food and Drink
# Payment
# Food and Drink
# Shops
# Payment
# Travel
# Transfer
# Transfer
# Recreation
# Travel
# Food and Drink
# Food and Drink
# Food and Drink
# Transfer
# Travel
# Travel
# Food and Drink
# Payment
# Food and Drink
# Shops
# Payment
# Travel
# Transfer
# Transfer
# Recreation
# Travel
# Food and Drink
# Food and Drink
# Food and Drink
# Transfer

# %% [markdown]
# ### 3. Create a new DataFrame using the following fields from the JSON transaction data: `date`, `name`, `amount`, `category`.
#
# (For categories with more than one label, just use the first category label in the list)

# %%
# Define an empty DataFrame and set the columns as date, name, amount, and category
dates = []
name = []
amount = []
categories = []

# Retrieve all the transactions
for transactions in transaction_response['transactions']:
    category = transactions['category'][0]
    categories.append(category)
    dates.append(transactions['date'])
    name.append(transactions['name'])
    amount.append(transactions['amount'])

# Populate the transactions DataFrame with the transactions data
df = pd.DataFrame(list(zip(dates, name, amount, categories)), columns = ['Date', 'Name', 'Amount', 'Category'])

# Display sample data from the DataFrame    
df.head(10)
# Out:
#          Date                                   Name   Amount        Category
# 0  2020-05-30                        United Airlines   500.00          Travel
# 1  2020-05-28                                   Uber     6.33          Travel
# 2  2020-05-25                             Tectra Inc   500.00  Food and Drink
# 3  2020-05-24              AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 4  2020-05-24                                    KFC   500.00  Food and Drink
# 5  2020-05-24                   Madison Bicycle Shop   500.00           Shops
# 6  2020-05-15           CREDIT CARD 3333 PAYMENT *//    25.00         Payment
# 7  2020-05-15                                   Uber     5.40          Travel
# 8  2020-05-14  ACH Electronic CreditGUSTO PAY 123456  5850.00        Transfer
# 9  2020-05-14                   CD DEPOSIT .INITIAL.  1000.00        Transfer

# %% [markdown]
# ### 4. Convert the data types to the appropriate types
#
# (i.e. datetimeindex for the date and float for the amount)

# %%
# Display data types
print(df.dtypes)
# Out:
# Date         object
# Name         object
# Amount      float64
# Category     object
# dtype: object

# %%
# Make any required data type transformation
df['Name'].astype('str')
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Set the date column as index
df.set_index('Date', inplace = True)

# Display sample data
df.head()
# Out:
#                                  Name   Amount        Category
# Date
# 2020-05-30            United Airlines   500.00          Travel
# 2020-05-28                       Uber     6.33          Travel
# 2020-05-25                 Tectra Inc   500.00  Food and Drink
# 2020-05-24  AUTOMATIC PAYMENT - THANK  2078.50         Payment
# 2020-05-24                        KFC   500.00  Food and Drink

# %% [markdown]
# ---

# %% [markdown]
# # Income Analysis with Plaid
#
# In this section, you will use the Plaid Sandbox to complete the following:
#
# 1. Determine the previous year's gross income and print the results
#
# 2. Determine the current monthly income and print the results
#
# 3. Determine the projected yearly income and print the results

# %%
# Fetch de income data
income = client.Income.get(access_token)
# Print the income data
print(json.dumps(income, indent = 4, sort_keys = True))
# Out:
# {
#     "income": {
#         "income_streams": [
#             {
#                 "confidence": 0.99,
#                 "days": 690,
#                 "monthly_income": 500,
#                 "name": "UNITED AIRLINES"
#             }
#         ],
#         "last_year_income": 6000,
#         "last_year_income_before_tax": 7285,
#         "max_number_of_overlapping_income_streams": 1,
#         "number_of_income_streams": 1,
#         "projected_yearly_income": 6085,
#         "projected_yearly_income_before_tax": 7389
#     },
#     "request_id": "yxCBfNRiJ6r6cUI"
# }

# %%
# Determine the previous year's gross income and print the results
previous_year_income = client.Income.get(access_token)['income']['last_year_income_before_tax']
print(previous_year_income)
# Out:
# 7285

# %%
# Determine the current monthly income and print the results
current_monthly_income = client.Income.get(access_token)['income']['income_streams'][0]['monthly_income']
print(current_monthly_income)
# Out:
# 500

# %%
# Determine the projected yearly income and print the results
projected_yearly_income = current_monthly_income * 12
projected_yearly_income
# Out:
# 6000

# %% [markdown]
# ---

# %% [markdown]
# # Budget Analysis
# In this section, you will use the transactions DataFrame to analyze the customer's budget
#
# 1. Calculate the total spending per category and print the results (Hint: groupby or count transactions per category)
#
# 2. Generate a bar chart with the number of transactions for each category
#
# 3. Calulate the expenses per month
#
# 4. Plot the total expenses per month

# %% [markdown]
# ### Calculate the expenses per category

# %%
# Compute the total expenses per category
expense_df = df.drop(columns = 'Name')
total_expense_category = expense_df.groupby(['Category']).sum()
total_expense_category.sort_values('Amount', ascending = False)
# Out:
#                   Amount
# Category
# Transfer        20537.34
# Payment          6310.50
# Food and Drink   3317.19
# Shops            1500.00
# Recreation        235.50
# Travel             35.19

# %%
# Display the expenses per catefory
total_expense_category.head()
# Out:
#                   Amount
# Category
# Food and Drink   3317.19
# Payment          6310.50
# Recreation        235.50
# Shops            1500.00
# Transfer        20537.34

# %%
# Create a spending categories pie chart.
total_expense_category.plot.pie(subplots=True,figsize=(15,8), title="Total Spending Per Category")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000021A3A847148>],
#       dtype=object)

# %% [markdown]
# ### Calculate the expenses per month

# %%
# Create a DataFrame with the total expenses
total_expense_df = df.filter(['Category', 'Amount']).groupby(['Category']).count()
# Display sample data
total_expense_df.head()
# Out:
#                 Amount
# Category
# Food and Drink      15
# Payment              6
# Recreation           3
# Shops                3
# Transfer             9

# %%
# Create a spending per month bar chart
total_expense_df.plot.bar(figsize=(15,8), title="Number of Transactions Per Category")
total_expense_df.sort_values('Amount', ascending = False, inplace = True)

# %% [markdown]
# ### Calculate Expense Per Month

# %%
exp_per_mo_df = df.filter(['Date', 'Amount'])
exp_per_mo_df.index = pd.to_datetime(exp_per_mo_df.index)

exp_group = exp_per_mo_df.groupby(exp_per_mo_df.index.month).sum()

# %%
exp_group
# Out:
#         Amount
# Date
# 3     10645.24
# 4     10645.24
# 5     10645.24

# %%
exp_group.plot(kind='bar',rot=0, title="Expenses Per Month", figsize=(12,7))
